# %%
from pyspark.sql import SparkSession
from langchain_text_splitters import RecursiveCharacterTextSplitter
import json
import os

# %%
spark = SparkSession.builder.appName('SparkApp').config('spark.driver.host', 'localhost').getOrCreate()

# %%
'''
Takes in a list of PDF file paths as input
and returns the loaded json as a python dictionary
'''
def read_esg_jsons(lst_of_json_path):
    res = []
    for json_path in lst_of_json_path:
        
        with open(json_path, 'r') as f:
            res.append(json.load(f))
    return res

'''
Takes in a dictionary with
<source_path>_<page_id> of PDF as key
and page text in string as value,
chunksize, chunk_overlap and separators
as inputs and returns a dictionary as an output
through the following process:

Splits each page into smaller tokens
and returns a dictionary where
the key is <source_path>_<page_id>_<token_num>
and value as token in string format
'''
def generate_page_id_num_tokenstr_pair(
        pageid_doc_d, 
        chunksize = 200, 
        chunk_overlap = 20, 
        separators = ["\n\n", "\n", " ", ""]
    ):
    # initialise text splitter
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size = chunksize,
        chunk_overlap = chunk_overlap,
        separators = separators
    )
    '''
    Splits each page into smaller tokens
    and returns a dictionary where
    the key is <source_path>_<page_id>_<token_num>
    and value as token in string format
    '''
    pageidnum_tokenstr_d = {f'{pageid}_{idx}': tokenstr\
                            for pageid, pagestring in pageid_doc_d.items()\
                            for idx, tokenstr in enumerate(text_splitter.split_text(pagestring))}
    return pageidnum_tokenstr_d

# %%
json_folder_dir = 'data/esg-json/'
lst_of_json_filename = os.listdir(json_folder_dir)
lst_of_json_paths = [json_folder_dir + json_filename for json_filename in lst_of_json_filename]
lst_of_jsons = read_esg_jsons(lst_of_json_paths)
lst_of_tokenized_jsons = [
    generate_page_id_num_tokenstr_pair(loaded_json, 200, 10, ["\n\n", "\n", " ", ""])
    for loaded_json in lst_of_jsons
]

# %%
lst_of_tokenized_jsons
# Out:
# [{'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_0_0': 'Aramco\nSustainability Report 2023\nInvesting in growth \nInnovating for sustainability',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_0': 'ARAMCO | SUSTAINABILITY REPORT 2023\n01\nAbout this report\nWe are Aramco, one \nof the world’s largest \nintegrated energy and \nchemicals companies\nOur vision',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_1': 'Aramco’s vision is to be the world’s preeminent \nintegrated energy and chemicals company, operating \nin a safe, sustainable, and reliable manner.\nOur mission',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_2': 'Aramco strives to provide reliable, affordable, and \nmore sustainable energy to communities around the \nworld, and to deliver value to its shareholders through',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_3': 'business cycles by maintaining its preeminence in oil \nand gas production and its leading position in \nchemicals, aiming to capture value across the energy',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_4': 'value chain and profitably growing its portfolio.\nOur approach to sustainability reporting\nIn our third Sustainability Report, we present how we',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_5': 'integrate sustainability within our corporate strategy \nand operations; the material sustainability issues that \nimpact our business and stakeholders; a summary of',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_6': 'key initiatives; and our sustainability performance \nduring 2023. \nSustainability for Aramco is about being a responsible \ncorporate citizen environmentally, socially and',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_7': 'economically. This is underpinned by our four focus \nareas (Climate change and the energy transition,  \nSafe operations and people development, Minimizing',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_8': 'environmental impact, and Growing societal value), \nwhere we elaborate on what sustainability means \nfor Aramco and set our relevant ambitions, targets \nand metrics.\nReporting standards',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_9': 'The following sections of this report have been \nprepared with reference to and/or guidance from \nthe following frameworks, standards, and guidelines:\n• Reporting guidelines for our Environment,',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_10': 'Social and Governance (ESG) disclosures: Ipieca;\n• For measuring and reporting our greenhouse gas \n(GHG) emissions: Greenhouse Gas Protocol; and \n• For reporting our health and safety performance',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_11': 'metrics: Occupational Safety and Health Administration \n(OSHA) Standards and the American Petroleum \nInstitute Recommended Practices.\nReporting boundaries, scope, and basis  \nof preparation',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_12': 'This report contains data for the full year 2023 \n(January 1 – December 31). Where available, \nwe have compared the 2023 performance with \n2022 and 2021 data.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_13': 'For clarity and transparency, the specific reporting \nboundaries of each metric for 2023, 2022, and 2021 \ndata have been noted in detail on page 100 in the \nData section of this report.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_14': 'Acquisitions made during 2023 will not be reportable \nuntil after the first full year of operation. Therefore, \nacquisitions made during 2023 will be reportable',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_15': 'from FY2025 onwards. Any wholly-owned sites that \nare not fully operational are excluded from reporting \nuntil effective data controls and systems are in place.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_16': 'The basis of preparation on how we measure and \nreport on the sustainability performance metrics \nthat undergo external independent assurance can \nbe found online .',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_17': 'SABIC and S-Oil’s sustainability data are not in the \nscope of this report. Both subsidiaries are publicly \nlisted and issue separate annual sustainability reports.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_18': 'Internal controls and data validation\nAll figures in this report represent the latest \navailable, internally validated data, unless specifically \nreferenced. Some of the totals presented may reflect',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_19': 'the rounding-down or rounding-up of subtotals. \nAramco’s internal reporting systems capture and record \nthe data used in this report. All data has been subject',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_20': 'to internal validation, including data reviews by the \nreporting businesses and internal subject matter experts. \nThird-party limited assurance\nThird-party limited assurance has been sought',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_21': 'against various key performance metrics, including \nGHG emissions, in accordance with the revised \nInternational Standard on Assurance Engagements \n3000 (ISAE 3000 revised). Data that has undergone',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_22': 'assurance has been referenced throughout the \nreport. More information on assured data and the \nassurance statements can be found online .\nOverview     \n2023 at a glance    02\nOur history    06',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_23': 'Chairman’s message    08\nPresident and CEO’s message  09\nValue of oil and gas   10\nPositioning Aramco for the future  12\nOur approach to sustainability  16\nOur stakeholder engagement  20',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_24': 'Governance     94\nData       \nOur metrics    102\nAbbreviations, terms, and glossary  107\nForward-looking statements  112\nContents\nOur sustainability focus areas\nClimate change and',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_25': 'the energy transition\nMinimizing \nenvironmental impact\n** External limited assurance symbol  \nThe figures within this report have undergone external \nlimited assurance in accordance to the ISAE 3000',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_26': '(revised). The relevant information are marked with  \nthis symbol.\nOur 2023\nSustainability Report\nInvestors\nDownload our report (PDF) Sustainability quick read',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_27': 'We present our approach to: integrating sustainability\nwithin our corporate strategy and operations.\nAnnual Report 2023\nOur 2023\nSustainability\nReport\nDownload the report (PDF)',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_28': 'Sustainability quick read\nWe present our approach to:\nintegrating sustainability\nwithin our corporate strategy\nand operations.\n J  The assurance reports can \nbe found online  on the',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_29': 'Sustainability section of \nour website.\nAssured data\nPage 22 Page 50\nPage 78Page 64\nSafe operations and \npeople development\nGrowing \nsocietal value',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_30': 'Cover image: Shaybah is a prize-winning example of our ability to plan for and meet global energy demand, and do it in harmony with the natural environment.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_1_31': 'Shaybah’s reserves alone can supply the entire world’s oil requirements for over 160 days (and Europe’s for over two years).\nLearn more about Shaybah online',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_0': 'ARAMCO | SUSTAINABILITY REPORT 2023 ARAMCO | SUSTAINABILITY REPORT 2023\n0302\nOVERVIEW\nCLIMATE CHANGE  \nAND THE ENERGY \nTRANSITION\nSAFE OPERATIONS  \nAND PEOPLE \nDEVELOPMENT\nMINIMIZING \nENVIRONMENTAL',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_1': 'IMPACT\nGROWING  \nSOCIETAL VALUE GOVERNANCE DATA\n2023 at a glance\nOur business performance\nInputs\nOperations\nTotal hydrocarbon reserves 1\n(billion boe)\n251.2\nMaximum sustainable capacity\n(MMbpd)\n12.0',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_2': '12.0\nNet chemicals production capacity 10\n(MMtpa)\n59.6\nNet refining capacity\n(MMbpd)\n4.1\nRelationships\nExternal stakeholders 4\n• Customers  • \u2002Suppliers\n• Partners  • \u2002Governments',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_3': '• Communities • \u2002Investors\nCountries of operations\n50+\nFinancial\nCapital expenditure 2\n(billion)\n$42 SAR 158\nNet cash 3\n(billion)\n$27 SAR 103\nAverage capital employed 3\n(billion)\n$545 SAR 2,043',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_4': 'Human\nCompany employees\n73,311\nNationalities\n94*\nOutcomes and impacts\nOperations\nProducts produced\n• Crude oil\n• Gas\n• NGL\n• Condensate\n• Chemicals\n• Refined products\n• Base oils and lubricants',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_5': '• Electricity\n• Blue ammonia\n• Nonmetallics\nUpstream carbon intensity 5\n(kg CO2e/boe)\n9.6\n**\nReliability 6\n(%)\n99.8\nScope 1 emissions\n(MMtCO2e)\n54.4\n**\nScope 2 emissions 5\n(MMtCO2e)\n13.0\n**',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_6': '13.0\n**\nPower supplied to the national grid\n(gigawatts)\n1.1\nFreshwater consumption\n(million m3)\n89.9\n**\nRelationships\niktva procurement spend in-Kingdom\n(%)\n65.0\nPayments to Saudi and foreign',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_7': 'governments 7\n(billion)\n$205 SAR 769\nFinancial\nNet income\n(billion)\n$121 SAR 455\nFree cash flow 9\n(billion)\n$101 SAR 380\nDividends paid 8\n(billion)\n$102 SAR 381\nReturn on Average Capital',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_8': 'Employed (ROACE) 9\n(%)\n22.5\nHuman\nLost time injuries/illnesses rate\n(per 200,000 work hours)\n0.018\n**\nTotal recordable case rate\n(per 200,000 work hours)\n0.042\nTier 1 process safety events\n15',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_9': '15\nFatalities\n3\n**\nMidOcean Energy acquisition\nAramco entered the global LNG business by signing a \ndefinitive agreement in September 2023 to acquire a',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_10': 'minority stake in MidOcean, enabling Aramco to tap \ninto international LNG opportunities. \nOil from plastic waste\nAramco, TotalEnergies, and SABIC have for the first',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_11': 'time in the Middle East and North Africa successfully \nconverted oil derived from plastic waste into \nInternational Sustainability and Carbon Certification \n(ISCC+) certified circular polymers.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_12': 'Investment in Rongsheng Petrochemicals \nA $3.4 billion deal advances Aramco’s liquids-to-\nchemicals strategy, increasing our presence in China.\nSiemens Direct Air Capture (DAC) partnership',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_13': 'Aramco collaborated  with Siemens Energy to develop \na DAC test unit in Dhahran that could pave the way \nfor a larger plant.\nInvestment in solar projects',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_14': 'Entered into a shareholders’ agreement to develop \ntwo photovoltaic solar projects in Al Shuaibah with  \na planned combined capacity of 2.7 GW.\nWorld Economic Forum (WEF) Global Lighthouse',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_15': 'Yanbu Refinery becomes fourth Aramco facility  \nto receive the WEF Global Lighthouse Network status.\nA year of delivering on our strategy\n2. Capital expenditures do not include external investments.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_16': '3. For definition of average capital employed and net cash, refer to “Non-IFRS measures \nreconciliations and definitions" section on page 36 in the Aramco Annual Report 2023.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_17': '4. Refer to page 20 for more information on our stakeholders and how we work with them.\n5. In 2023, along with the location-based methodology we have reported to date, we adopted',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_18': 'the market-based methodology to calculate and report on our GHG emissions to avoid \ndouble counting of emissions associated with wheeled power, in line with GHG Protocol',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_19': 'Scope 2 Guidance. Therefore, the figures reported for upstream carbon intensity and Scope \n2 emissions are market-based. For 2023, the location-based figures for upstream carbon',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_20': 'intensity and Scope 2 emissions are 10.7 kg CO2e/boe and 18.2 MMtCO2e, respectively. For \nmore information on our GHG methodology, please refer to page 30 of this report.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_21': '6. Applies to Saudi Arabian Oil Company (the Company).\n7. Includes income taxes, royalties, and dividends to the Saudi government.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_22': '8. Dividends paid includes dividends to shareholders and non-controlling interests in subsidiaries.\n9. Non-IFRS measure: refer to “Non-IFRS measures reconciliations and definitions"',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_23': 'section on page 36 in the Aramco Annual Report 2023.\n10. Excludes SABIC Agri-Nutrients and Metals (Hadeed) businesses.\n* Metric reported for the first time externally.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_24': '**\u2002This figure has undergone/is undergoing external limited assurance in accordance to \nthe ISAE 3000 (revised). Upon completion of assurance, theassurance report can be',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_25': 'found online  on the Sustainability section of our website.\n1. Hydrocarbon reserves of Saudi Arabian Oil Company (the Company) as at \nDecember 31, 2023, under the Concession agreement.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_26': 'Liquids-to-chemicals expansion\nAramco and its affiliate, S-Oil, commenced \nconstruction of the $7 billion Shaheen project in \nSouth Korea to develop one of the world’s largest',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_27': 'refinery-integrated petrochemical steam crackers. \nThis represents a significant step forward in our \nliquids-to-chemicals expansion. \nValvoline Inc.’s acquisition',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_28': 'Aramco completed the $2.76 billion acquisition  \nof Valvoline Inc.’s global products business, \naccelerating the company’s vision to become \none of the world’s preeminent integrated energy',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_29': 'and chemicals companies.\nDeveloping new ammonia cracking technology \nSigned an agreement with Linde Engineering to \njointly build a demonstration plant to test a new',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_30': 'ammonia cracking technology in Germany. \nThree blue ammonia shipments \nAramco delivered three shipments of accredited,  \nblue ammonia through its affiliates ATC and SABIC \nAgri-Nutrients.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_31': 'First-of-its-kind synthetic fuel demonstration plant\nAramco and ENOWA to develop first-of-its-kind \nsynthetic fuel demonstration plant.\nPowering engines through lower-carbon fuels',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_32': 'Aramco and Stellantis collaboration finds Aramco-\nprovided synthetic fuel compatible with 24 engine \nfamilies in Europe. The use of lower-carbon synthetic',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_2_33': 'fuel can reduce CO2 emissions from existing vehicles.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_0': 'ARAMCO | SUSTAINABILITY REPORT 2023 ARAMCO | SUSTAINABILITY REPORT 2023\n0504\nOVERVIEW\nCLIMATE CHANGE  \nAND THE ENERGY \nTRANSITION\nSAFE OPERATIONS  \nAND PEOPLE \nDEVELOPMENT\nMINIMIZING \nENVIRONMENTAL',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_1': 'IMPACT\nGROWING  \nSOCIETAL VALUE GOVERNANCE DATA\n2023 at a glance\n• Established the New Energies organization \nfollowing the endorsement of our long-term',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_2': 'strategy to achieve lower-carbon solutions and  \nfor Aramco to meet its GHG emissions mitigation \nand abatement ambitions \n• Upstream methane emissions reduction by 5.1% and',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_3': 'upstream methane intensity maintained at 0.05%**\n• Energy efficiency initiatives resulting in avoidance  \nof 0.73 MMtCO 2e\n• Played a key role in Oil and Gas Decarbonization',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_4': 'Charter, a global industry charter established at  \nCOP 28 and signed by more than 50 oil and natural \ngas companies\n• Largest buyer of carbon credits in the',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_5': 'Regional Voluntary Carbon Market Company’s \nsecond auction in Nairobi, Kenya in June 2023',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_6': '** This figure has undergone/is undergoing external limited assurance in accordance to the ISAE 3000 (revised). Upon completion of assurance, the assurance report can be found online',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_7': 'on the Sustainability section of our website.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_8': '1. The Jazan Refinery is excluded from our GHG reporting in 2022 and 2021. In 2023, only the stabilized units of Jazan Refinery are included in our GHG metrics reporting.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_9': '2. In 2023, along with the location-based methodology we have been reporting in our disclosures to date, we have also adopted a market-based methodology to calculate and report on',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_10': 'our GHG emissions to avoid double counting of emissions associated with wheeled power, in line with GHG Protocol Scope 2 Guidance. Therefore, the figures reported for upstream',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_11': 'carbon intensity and Scope 2 emissions are market-based. For 2023, the location-based figures for upstream carbon intensity and Scope 2 emissions are 10.7 kg CO2e/boe and 18.2',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_12': 'MMtCO 2e, respectively. For 2022, the location-based figures for upstream carbon intensity and Scope 2 emissions are 10.3 kg CO2e/boe and 16.1 MMtCO 2e, respectively. For more',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_13': 'information on our GHG methodology, please refer to page 30 of this report.\nOur sustainability performance\nOur focus areas \nAramco has an important role in helping the world',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_14': 'navigate the energy transition. What we do as a \nglobal community will determine the legacy we leave \nfor future generations. \nOur intention is to be a part of the solution that',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_15': 'creates a stable energy environment that fosters \ninnovation and growth opportunities in developing \nand developed countries.\nWe also aim to deliver a healthy, safe, and rewarding',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_16': 'environment for our people, our suppliers and \ncommunities where we operate while rehabilitating \nand mitigating the impact on our natural environment.\nClimate change and \nthe energy transition',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_17': 'We aim to provide affordable, reliable energy \nas one of the lowest upstream carbon intensity \nproducers of hydrocarbon products; while we \ncontinue our ambition to achieve net-zero',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_18': 'Scope 1 and Scope 2 GHG emissions across \nwholly-owned operated assets by 2050.\n J For more details, see page 22\nScope 1 emissions 1\n(MMtCO 2e)\n54.4\n**\n(2022: 55.7 ** )\nScope 2 emissions 1,2',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_19': '(MMtCO 2e)\n13.0\n**\n(2022: 10.3 ** )\nUpstream carbon \nintensity\u200a 2\n(kg CO 2e/boe)\n9.6\n**\n(2022: 9.3 ** )\n• Aramco achieved historic hiring levels,  \nreaching over 73,300 employees',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_20': '• Over 20% of direct hires were female\n• 26.3% increase in the percentage of female \nemployees in leadership positions\n• The National Training Centers have collectively',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_21': 'had 57,943 graduates since inception\n• Largest-ever College Preparatory Program  \ncohort to graduate with 358 students\n• More than 2,000 students benefited from the',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_22': 'Intermediate Science, Technology, Engineering, \nand Mathematics (STEM) program in \ncollaboration with the Ministry of Education\n• Aramco’s total recordable case rate improved',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_23': 'by 16.0% in 2023 and represents the best \nCompany  performance on its record\nSafe operations and \npeople development\nWe aim to provide a safe and respectful \nworking environment for all, on-site',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_24': 'and within the community, supported by \ncomprehensive policies, and resources. We \nstrive to support, diversify, and empower our \nworkforce.\n J For more details, see page 50\nTier 1 process',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_25': 'safety events\n(number)\n15\n(2022: 11)\nFatalities\n(number)\n3\n**\n(2022: 5 ** )\nFemale employees\n(%)\n7.2\n(2022: 6.4)\n• Achieved 100% **  ISO 14001 certification at',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_26': '52 upstream and downstream asset-based \norganizations enrolled in Aramco’s \nEnvironmental Management System (EMS)\n• Continued upgrading Sulfur Recovery Units \n(SRU) with tail gas treatment units',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_27': '• Designated additional Biodiversity  \nProtection Areas (BPAs), bringing the  \ntotal number of BPAs to 14\n• Continued pursuing a water neutrality \naspiration',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_28': '• Planted approximately 6.5 million mangroves \nand an additional 1.1 million native trees\n• Continued commitment to building the capacity  \nof locals with over 24% (15,099 in 2023 versus',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_29': '12,160 in 2022) increase in the number  \nof people in our sponsored2 community programs\n• Providing growth acceleration services, via the \nTaleed program, to support small and',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_30': 'medium-sized enterprises (SMEs) sustainability \nand scale up including partnership and network \nbuilding, business development, and attracting \ninvestments',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_31': '• Social investments3 of $475 million were made in \nSaudi Arabia and abroad\n• Aramco and its employees donated over  \n$18 million for disaster relief globally\nMinimizing \nenvironmental  \nimpact',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_32': 'impact\nWe strive to conserve natural resources,  \napply circular models across our value  \nchain, and to have a legacy of projects  \nthat improve both natural habitats and  \nshared resources.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_33': 'J For more details, see page 64\nGrowing  \nsocietal value\nWe seek to grow value wherever we operate. \nWith our headquarters in Saudi Arabia, we \nhave invested in the Kingdom’s oil and gas',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_34': 'ecosystem to enhance the reliability of our \nsupply chain, providing employment and \neconomic opportunities to thousands of  \nSaudi nationals.\n J For more details, see page 78\nNet positive impact',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_35': 'on biodiversity\n(%)\n85.6\n**,1\n(2022: 53 ** )\nHydrocarbon spills\n(number)\n12\n(2022: 15)\nFreshwater \nconsumption\n(million m3)\n89.9\n**\n(2022: 93.6 ** )\niktva procurement \nspend in-Kingdom\n(%)\n65',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_36': '(%)\n65\n(2022: 63)\nSaudization\n(%)\n90.3\n(2022: 90.9)\nSocial investment 3\n($ million)\n475\n(2022: 453)\nWe have four focus areas that provide an overview of',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_37': 'how Aramco manages its sustainability performance:\n• Climate change and the energy transition;\n• Safe operations and people development;\n• Minimizing environmental impact; and',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_38': '• Growing societal value.\nUnderpinning these focus areas are metrics. \nIncreasing metrics is important for us, as we would \nnot be able to manage our sustainability performance',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_39': 'effectively, without having meaningful metrics that \nmeasure our sustainability impact. \nTherefore, we are pleased to share that in our third',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_40': 'sustainability report, as we continue to progress on our \nsustainability journey, we have a 21% increase in the \nnumber of metrics in this report (74 metrics versus the',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_41': '61 metrics in our 2022 Sustainability Report), and have \nexpanded the number of metrics undergoing external \nassurance to 18 metrics (16 metrics in our 2022 \nSustainability Report).',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_42': '** This figure has undergone external limited assurance in accordance to the ISAE 3000 (revised). The assurance report can be found online on the Sustainability section of our website.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_43': '1.  Ongoing management and review of the BPAs resulted in exclusion of the Manifa BPA from our NPI metric as a BPA, pending implementation of enhancements to align with the',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_44': 'Company’s biodiversity governance.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_45': '2. These programs include the Vocational College Internship Program (VCIP), University Internship Program (UIP), Summer enrichment program, Tomooh program, Advantage program,',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_46': 'and Arizona Centers for Comprehensive Education and Life Skills (ACCEL) International Ajyal Center.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_47': '3. Updated methodology: this is the first year we are reporting on the costs of running Aramco-built schools, as part of our social investment. We have also revised the prior year figure',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_3_48': 'to reflect this change. With this updated methodology, the 2022 figure is now $453 million compared to $370 million under the previous methodology.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_0': 'OVERVIEW\nCLIMATE CHANGE  \nAND THE ENERGY \nTRANSITION\nSAFE OPERATIONS  \nAND PEOPLE \nDEVELOPMENT\nMINIMIZING \nENVIRONMENTAL \nIMPACT\nGROWING  \nSOCIETAL VALUE GOVERNANCE DATA',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_1': '07ARAMCO | SUSTAINABILITY REPORT 2023\nOur history\n06 ARAMCO | SUSTAINABILITY REPORT 2023\n1933-1945\nThe birth of Arabian oil\n1933\nThe beginning: unlocking the \nKingdom’s vast oil resources',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_2': 'with the crude oil Concession \nagreement (signed with \nStandard Oil of California)\n1940\nBeyond employment:\nproviding additional \neducational opportunities  \nfor Saudis\n1941\nBoosting agriculture:',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_3': 'surveying land and drilling \nwells to provide valuable \nwater for farmers\n1943\nEmployee health: helping  \nlocal communities to  \neradicate malaria\n1946-1959\nSetting our sustainability \nfoundations',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_4': '1946\nDeveloping local supply \nchains: providing technical  \nand financial assistance to \nSaudi entrepreneurs\n1949\nIn-house training: investing  \nin on-the-job technical and \nadministrative training',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_5': '1950s\nBuilding leaders: offering \nscholarships to study in the US \nto top-performing Saudis\n1960-1975\nTaking bold leaps forward\n1960\nFemale education: building \nelementary schools for girls',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_6': 'in the Eastern Province\n1975\nMaster Gas System: Decision \nmade to build the Master Gas \nSystem, enabling one of the \nworld’s largest gas markets, \ntransforming the national',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_7': 'energy mix toward natural gas \nand building the cornerstone for \nthe economy’s industrialization\n1978\nGroundwater protection: \nEstablishing the Qurayyah  \nSea Water Plant to support',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_8': 'our operations and  \nconserve groundwater \n90 years driving  \nsustainable growth\n1976-1989\nBecoming the world’s \nlargest oil producer \n1976\nBecame the world’s leading oil',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_9': 'producer in terms of volume \nproduced in a single year\n1988\nSaudi Arabian Oil Company \nofficially established\n1990-2004\nProtecting resources and \nreducing emissions\n1990s\nProtecting ecosystems:',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_10': 'responding swiftly and \nefficiently to the Gulf War  \noil spills\nReduced lead content fuels: \nhalved the lead content \nof produced gasoline,  \nand ceased production \nof leaded gasoline entirely',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_11': 'by the end of 2001\n1993\nMangrove restoration: first \nmangrove trees planted\n2001\nRecycling and reuse: devising \ninnovative applications for \nAramco’s wastewater\n2005-2020\nInnovative sustainable',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_12': 'solutions \n2009\nFlare monitoring system: \ndevelopment of an in-\nhouse system driving flare \nreduction results\n2013\nSustainable offices: the new \nAl-Midra offices achieves',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_13': 'LEED platinum certification \n(Leadership in Energy and \nEnvironmental Design)\n2015\nAccelerating change: founding \nmember of the Oil & Gas  \nClimate Initiative (OGCI)\nHawiyah carbon capture,',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_14': 'Utilization and storage pilot: \nCapacity to capture 800,000 \ntons CO₂ per annum\nDomestic value creation: \nlaunch of iktva (in-Kingdom \nTotal Value Add) program\n2016\nNurturing biodiversity:',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_15': 'reintroduction of oryx  \nand gazelle in Shaybah \nWildlife Sanctuary\n2017\nUsing alternatives: installing \nthe Kingdom’s first wind \nturbine at the Turaif Bulk Plant\n2018\nCultural enrichment: opening',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_16': 'of Ithra – the King Abdulaziz \nCenter for World Culture\n2019\nBringing hydrogen to the  \nlocal market: inaugurating \nSaudi Arabia’s first hydrogen \nfueling station\n2020\nBlue ammonia: world first',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_17': 'shipment of blue ammonia, \nopening new routes to a more \nsustainable future \n2021-2023\nTransformation  \nand energy security\n2021\nSudair renewable project: Aramco \njoined a consortium to develop a',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_18': '1.5 GW solar plant\nFirst Sustainability Report: Aramco \nissues its first sustainability report, \noutlining what sustainability is for \nAramco and how we manage it \nNet-zero: Aramco announced',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_19': 'its ambition to achieve net-zero \nScope 1 and Scope 2 greenhouse \ngas emissions by 2050 from our \nwholly-owned operated assets \n2022\nNet-positive biodiversity: \nannounced ambition to deliver',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_20': 'a net positive impact, building  \non our work in over 985 km 2   \nof protected areas \nSustainability Fund: Aramco \nestablished a new $1.5 billion \nSustainability Fund to invest in',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_21': 'technologies needed to address \nclimate challenges \nCarbon capture and storage: \nSigned an agreement to construct \none of the world’s largest planned \ncarbon capture and storage hubs',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_22': 'Blue ammonia and blue hydrogen: \nGranted the first certification for \nblue ammonia and blue hydrogen \nfor SASREF/SABIC AN\n2023\nExpanding renewable energy: \nAgreed to invest in the Al Shuaibah 1',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_23': 'and Al Shuaibah 2 photovoltaic \nsolar projects which are expected \nto have a combined capacity  \nof 2.7 GW\nCircular economy: Aramco, \nTotalEnergies and SABIC complete',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_4_24': 'MENA region’s first processing of \noil from plastic waste at scale to \nmake certified circular polymers',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_0': 'ARAMCO | SUSTAINABILITY REPORT 2023 ARAMCO | SUSTAINABILITY REPORT 2023\n0908\nOVERVIEW\nCLIMATE CHANGE  \nAND THE ENERGY \nTRANSITION\nSAFE OPERATIONS  \nAND PEOPLE \nDEVELOPMENT\nMINIMIZING \nENVIRONMENTAL',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_1': 'IMPACT\nGROWING  \nSOCIETAL VALUE GOVERNANCE DATA\nIn 2023, we celebrated the 90th anniversary of  \nthe Kingdom signing the Concession agreement.  \nThe milestone was an opportunity to reflect on our',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_2': 'Company’s remarkable longevity and the source of \nour enduring success. As we look back with pride \nover the past nine decades, one common thread \nemerged: an unwavering commitment to the long-',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_3': 'term prosperity of our communities, our customers, \nand our stakeholders.\nThroughout our history, that commitment has \nalways required us to carefully balance short-term',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_4': 'and long-term needs. It is a responsibility that has \ntaken on even greater urgency with the risks posed \nby climate change. How to facilitate the transition',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_5': 'toward a more climate-conscious tomorrow \nwithout disrupting the manufacturing, trade, and \ntransportation that are so essential to billions of lives',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_6': 'today is one of the defining challenges of our time.\nSupporting the energy transition\nAramco is intent on being part of the global solution. \nWith the world’s energy demand continuing to grow,',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_7': 'we are striving to ensure reducing GHG emissions \nin our conventional energy – which remains critical \nto meeting demand. We are pursuing a variety of',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_8': 'pathways to achieve that objective, including by \nimproving the energy efficiency of our operations, \nminimizing flaring and further reducing our GHG',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_9': 'emissions. These efforts have helped us to attain an \nupstream carbon intensity that is ranked among the \nlowest in the industry. \nWe know that global net-zero ambitions cannot be',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_10': 'achieved solely by reducing the emissions associated \nwith conventional energies. The success of the \ntransition to a lower emissions future will also hinge',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_11': 'on the availability of multiple lower carbon options, \nsome of which may be more suitable in certain \ncontexts than others. That is why we are pursuing',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_12': 'the development and deployment of technologies \nand tools that can contribute to global emission \nreduction efforts, including carbon capture and',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_13': 'storage, “drop-in” lower-carbon fuels, blue hydrogen, \nrenewables, and offsets. \nWe have also more than doubled the funding for \nour global venture capital arm, with half of the',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_14': 'additional $4 billion being injected into Aramco \nVentures earmarked for investment in late-stage, \nlarger-ticket ventures in the sustainability and \ndigital domains.\nFocusing on sustainability',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_15': 'In this report, we elaborate on our sustainability-\nrelated ambitions, targets and metrics as well as \nour progress to date. It is worth also noting that for',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_16': 'Aramco, sustainability means going above and \nbeyond just being a reliable supplier of energy to \ncustomers around the world. It also means being a',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_17': 'responsible corporate citizen environmentally, socially \nand economically. This is underpinned by our focus \non addressing climate change as part of the global',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_18': 'energy transition, maintaining safe operations \nwhile ensuring people development, minimizing \nenvironmental impacts, and also continuing to grow \nsocietal value.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_19': 'Throughout 2023, I am proud to say that Aramco \nmaintained positive momentum in each of these \nareas due to the dedication of our talented team of \nemployees. Our accomplishments would also not',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_20': 'have been possible without the continued support \nand vision of The Custodian of the Two Holy Mosques \nKing Salman bin Abdulaziz Al-Saud, and His Royal \nHighness Prince Mohammed bin Salman bin',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_21': 'Abdulaziz Al-Saud, Crown Prince and Prime Minister \nof the Kingdom of Saudi Arabia.\nClearly, the global transition to a lower carbon future \nis a complex journey rather than a singular event.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_22': 'What is also clear is that Aramco has a key role to \nplay in this energy transition.\nH.E. Yasir O. Al-Rumayyan\nChairman of the Board of Directors\nInvesting  \nin growth',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_23': 'in growth\nAramco’s role as the indispensable partner to a \nrealistic and robust energy transition puts us in a \nunique position. We take the responsibility seriously',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_24': 'and have put sustainability at the heart of our \nstrategy. Old problems are being met with new \nsolutions and I am proud of what we have achieved.\nCollaborating to drive more sustainable solutions',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_25': 'Collaboration is a key part of our approach and  \nwe have been working with Siemens Energy on a \nbrand-new Direct Air Capture test unit at our Dhahran',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_26': 'base in Saudi Arabia. This new test unit is expected to \nhave the capacity to capture up to 12 tons of CO2 from \nthe atmosphere per year and could pave the way for a',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_27': 'larger plant with the ability to capture more than \n100 times that amount.\nAlongside Danish technology leader Topsoe, we have \nplans to build a lower-carbon hydrogen production',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_28': 'demonstration plant at Shaybah, deep in the desert. \nWe expect to have a production capacity of six tons  \nof hydrogen per day and use renewable electricity in',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_29': 'electrified steam reforming of hydrocarbons to \nproduce lower-carbon hydrogen for use in power \ngeneration, with resulting CO2 being captured  \nand sequestered.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_30': 'On carbon sequestration, we have piloted a novel \nmethod with our partners at King Abdullah University \nof Science and Technology using situ mineralization',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_31': 'which involves dissolving CO2 in water and injecting it \ninto volcanic rocks. This process permanently converts \nCO 2 into carbonate rocks, and has led to the',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_32': 'development of innovative technologies that reduce \ncost and increase efficiency. \nOur partnerships also extend to our Downstream \nbusiness where we furthered our long-term goal',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_33': 'of directing up to four million barrels per day into \nliquids-to-chemicals by 2030. In Asia we broke \nground on two integrated refinery and petrochemical',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_34': 'complexes, one through our affiliate S-Oil in South \nKorea and another through a joint venture, HAPCO, \nin China. We also acquired a 10% stake in Chinese \npetrochemical company, Rongsheng.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_35': 'Supporting local communities and economic growth\nOur Namaat industrial investment program continues \nto support new industries in the Kingdom. One such',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_36': 'example from 2023 is the establishment of an integrated \nsteel plate manufacturing complex in Ras al-Khair \nIndustrial City. This joint venture with Baosteel and',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_37': 'the Public Investment Fund will be the first facility of \nits kind in the region, creating jobs and growing the \neconomy. It is also expected to help localize our',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_38': 'supply chain, an important iktva objective.\nA Novel Non-Metallic Solutions joint venture with \nBaker Hughes is another supply chain localization \nsuccess. The development and commercialization of',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_39': 'nonmetallic products at the King Salman Energy Park \nis helping create a thriving in-Kingdom energy value \nchain. The nonmetallic reinforced thermoplastic pipes',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_40': 'being produced are corrosion resistant and easier to \ninstall. This means that as well as the localization \nbenefits in production this new material also mitigates \ncarbon in the field too.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_41': 'On production, hydrocarbons will increasingly \nbe used without combustion, providing essential \ningredients for new and innovative materials \nneeded for the energy transition.',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_42': 'Maintaining a culture of safety\nSafety is always at the front of our minds and \ndespite a continual improvement for recorded \nincidents at Aramco facilities, we regrettably suffered',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_43': 'the loss of three lives from our team of contractors. \nThorough investigations have been carried out to \navoid reoccurrences, the learnings from which',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_44': 'have been shared with relevant teams. No loss of \nlife is acceptable and we are committed to \nmaintaining a culture of safety excellence.\nLiving our values',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_45': 'This year’s report demonstrates the progress we \nas a company are making to encourage sustainability \nin our operations and to support the Kingdom’s',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_46': 'sustainable development. I want to pay tribute to \nthose making it happen, as our plans are only as \ngood as our people. The men and women of Aramco',
#   'data/esg-pdf/2023-saudi-aramco-sustainability-report-full-en.pdf_5_47': 'stepped up again in 2023 to deliver for the company \nand those who rely on us. I am proud of the values \nthey demonstrate every day and know we will \ncontinue to make great strides together.',
# ...
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_58_12': 'Sustainability Champion: \nMatt Hellman \nI am a Sustainability Global Black Belt \n(GBB) at Microsoft, where I work with \ncustomers to achieve their sustainability',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_58_13': 'targets by adopting best practices and \ntechnology solutions. I am also a co-\nleader for the Sustainability Connected \nCommunity (SCC), a global network \nof employees at Microsoft who are',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_58_14': 'passionate about learning, inspiring \nothers, and activating sustainability in \ntheir lives and careers. Climate change is \nthe most urgent challenge we face, and',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_58_15': 'we all have a role to play in shaping our \nfuture. It is the intersection of making \na positive difference for the planet and \ndriving value for our customers and',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_58_16': 'partners that motivates and empowers \nme every day. \nAnalyzing and reporting \nESG performance \nAs the world shifts from voluntary to regulatory',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_58_17': 'environmental sustainability reporting, tools that can \nhelp capture and analyze data at scale will become \nincreasingly important. \nIn 2023, we introduced Project ESG Lake (Preview),',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_58_18': 'enabling organizations to centralize and standardize \ndata in a comprehensive ESG data estate. \nThis solution offers an expansive ESG data model \nthat organizations can use to transform data from',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_58_19': 'across business units and supply chains into a \nstandard schema ready for advanced analytics \nand reporting. \nTo help our customers track the required actions',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_58_20': 'and document evidence for emerging ESG reporting \nand compliance initiatives, we rolled out the first \nof several planned new reporting templates in \nMicrosoft Purview Compliance Manager.',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_58_21': 'For regulations coming from the European Union’s \nCorporate Sustainability Reporting Directive (CSRD), \nwe released the CSRD template (Preview). This new',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_58_22': 'template will help organizations to explore and plan \nfor the data required for CSRD and will enable data \ngovernance workflows to collect data for disclosures,',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_58_23': 'internally review disclosure data, and generate a \ndraft report for reviewed disclosure data.',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_0': '60Overview Microsoft sustainability Customer sustainability Global sustainability Appendix 60',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_1': 'Microsoft Cloud for Sustainability continued \nEmpowering organizations with \nguidance and training \nIn support of our goal of building a community of \nshared learning and action, in 2023 we:',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_2': 'Published new LinkedIn Learning modules to  \nshare learnings on how sustainability affects  \norganizations and how to minimize  \nenvironmental impacts.',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_3': 'Made technical guidance available within the \nAzure Well-Architected Framework, focused on \nworkload optimization strategies to help \norganizations build more sustainable IT.',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_4': 'Released new Well-Architected for Industry \nguidance to help organizations build Microsoft \nCloud for Sustainability workloads using proven \nbest practices and scalable principles for cloud',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_5': 'adoption and governance. \nOther tools created to empower customers on their \nsustainability journey include the Emissions Impact \nDashboard and Environmental Credit Service.',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_6': 'Emissions Impact Dashboard is a tool to improve \ntransparency into the carbon emissions generated \nby the use of Azure or Microsoft 365 cloud \nservices. Using third-party validated methodology,',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_7': 'the application factors in Microsoft’s Scope 1, \n2, and 3 (direct and indirect) emissions as well \nas the efficiency of a customer’s on-premises \nenvironment.12',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_8': 'Environmental Credit Service (Preview) is a managed \nservice under Microsoft Cloud for Sustainability \nthat provides a common infrastructure to track \nenvironmental credit provenance from creation',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_9': 'through retirement. This service helps decrease time \nto market and increase the quality and quantity of \ncredits—ultimately giving credit purchasers more',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_10': 'confidence and fueling marketplace momentum. \nTurning data into insights with AI \nAccess to more reliable data intelligence enables  \norganizations to make more targeted decisions',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_11': 'about their sustainability strategies. To help  \ncustomers perform advanced analytics and generate  \neven more detailed, actionable data insights, we',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_12': 'have built AI into many of our sustainability products  \nand solutions. New features in Microsoft Cloud for  \nSustainability such as Intelligent Insights, released',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_13': 'to preview in 2023, help organizations find outliers,  \ntrends, and correlations between their activity data  \nand calculated emissions through an integrated and',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_14': 'interactive AI model. These insights can inform more  \nimpactful decisions for companies and the planet.  \nAccelerating progress \nCompanies around \nthe world have begun  \nimplementing Microsoft',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_15': 'Cloud for Sustainability tools \nto improve sustainability and \nbusiness growth. \nOSTP Group, a Nordic-based manufacturer of  \nwelded stainless steel tubular products and',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_16': 'custom equipment for pressure corrosion  \napplications, prioritizes sustainability and has an  \nambitious target to be carbon neutral at its sites  \nby 2025. Using Microsoft technologies, including',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_17': 'Microsoft Cloud for Sustainability, OSTP built  \na digital platform to gather and report carbon  \ndioxide emissions data in real-time. Cloud for  \nSustainability helps OSTP measure emissions',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_18': 'accurately and in near-real-time and unify data  \nintelligence providing a more comprehensive view  \nof the impact of its operations and value chain.',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_19': 'Automation, transparency, and centralized visibility \nenable everyone from executives to frontline \nbusiness workers to access the data they need \nwhile spending less time on data collection.',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_59_20': 'AI capabilities in Microsoft Cloud for Sustainability \nwill aid faster decision making and help the \norganization optimize its roadmap.',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_0': '61Overview Microsoft sustainability Customer sustainability Global sustainability Appendix 61 \nDevices',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_1': 'Devices \nSustainability is a core part of our product \npromise—we work to create devices that are built \nwith integrity and with reduced waste and carbon \nimpact across their life cycles.',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_2': 'We are committed to reducing the carbon  \nintensity of our devices and we’ve made significant  \ninvestments in designing for a smaller manufacturing  \nfootprint by reducing waste, moving to more',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_3': 'efficient manufacturing processes, and increasing  \nthe use of recycled and repurposed materials.  \nThe Surface Thunderbolt™ 4 Dock uses 20% \nocean-bound plastic. \nDesigning and building',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_4': 'for circularity \nWe have embedded ecodesign principles, as \noutlined in the ISO/TR 14062 standard, into our \ninternal product development process, positioning',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_5': 'sustainability and circularity as foundational \nelements of innovation. \n 1 Starting at a new product’s inception, defined  \nroles and clear sustainability targets are set to',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_6': 'guide decision making throughout development.  \n2  During the initial design stages, screening life  \ncycle assessments (LCAs) are used to gauge  \npotential carbon reductions of various design',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_7': 'concepts and to assess circularity.  \n3  Upon the product launch, detailed LCAs measure  \nthe tangible achievements in carbon reduction  \nand circularity, offering valuable insights for',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_8': 'future design improvements. \nWe publish the carbon footprint \nof each device, along with other \nsustainability metrics, in our \nEco-profiles. Rigorous third-party \necolabels and standards provide',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_9': 'validation of our products’ \nenvironmental attributes \nand achievements. \nExtending the life of our devices \nDesigning for circularity conserves resources,',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_10': 'minimizes waste, and extends the lifespan of \nour devices. \nOur devices are designed to be easier to service \nand maintain so that customers have more flexibility',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_11': 'and opportunities to extend their use. As we design \nproducts that are easier to service with more \nreplacement components and expanded device \nservicing options, we also continue to grow our',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_12': 'service network to offer servicing alternatives closer \nto our customers. This encourages consumers to \nchoose servicing over replacement by removing \nperceived barriers and inconvenience, and by',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_13': 'reducing cost. \nThe newest generation of Surface Laptop, Surface  \nPro, and Surface Laptop Go lines are the most  \nrepairable devices in their product lines to date; and',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_14': 'for customers interested in self-service, we now offer  \nspare parts on the Microsoft Store.13 \nReducing the impact of \nproduct usage \nOur newest laptops and tablets are ENERGY STAR®',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_15': 'Certified and registered EPEAT® Gold in more than  \n30 countries. We continue to focus on increasing  \nthe energy efficiency of our devices to reduce  \ndirect emissions.',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_16': 'Our latest products are ENERGY STAR®  Certified,  \nconsuming less than the recommended energy \nlimit set by the latest ENERGY STAR® computer  \nspecification. For example, our Surface Laptop Go 3',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_17': 'uses 52% less energy and our Surface Laptop Studio  \n2 uses 65% less energy than the ENERGY STAR® limit.  \nSurface Emissions Estimator \nSince its inception, the emphasis for the Surface',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_18': 'Emissions Estimator has been to facilitate ease of use \nand accessibility for all Surface customers. This goal \nwas further heightened in September 2023, with',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_19': 'the tool accessible on a standalone webpage, and \nintegration into Microsoft Intune and the Surface \nManagement portal, thereby expanding its reach',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_20': 'to millions of new customers. This progress helped \nto establish a new benchmark for other device \nmanufacturers. We continue to work to embed \nCoPilot in Windows 11 chat functionality into the',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_21': 'Surface Emissions Estimator, aiming to demystify \ndata interpretation for customers, eliminating \nthe need for extensive knowledge in life cycle \nassessment or sustainability in order to understand',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_60_22': 'an individual’s emissions impact.',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_61_0': '62Overview Microsoft sustainability Customer sustainability Global sustainability Appendix 62 \nDevices continued \nXbox',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_61_1': 'Xbox \nXbox is the first gaming console to offer carbon-\naware game downloads and updates as part of  \nShutdown (energy saving) mode. We have made',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_61_2': 'significant strides in enhancing the energy efficiency  \nof these devices while simultaneously adopting  \ninnovative approaches to product design aimed at',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_61_3': 'reducing waste and increasing recyclability within  \nour Xbox controller lineup.  \nRecognizing that a substantial portion of emissions  \nin the Xbox value chain stems from console usage,',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_61_4': 'our primary focus over the past year has been to  \ntransition the majority of our players to Shutdown  \nmode. This Shutdown energy saving mode offers  \nup to 20 times reduction in power consumption',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_61_5': 'compared to the higher power Sleep mode.  \nImportantly, players still maintain the ability to  \ndownload updates for all their software while in  \nenergy saving mode.',
#   'data/esg-pdf/Microsoft-2024-Environmental-Sustainability-Report.pdf_61_6': 'We have also revamped the update process,  \npositioning the Xbox as the world’s first gaming  \nconsole with carbon awareness. This innovative  \nfeature means that when a console is plugged in,',
#   ...}]
